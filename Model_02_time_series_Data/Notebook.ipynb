# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# %pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("prachi13/customer-analytics")

print("Path to dataset files:", path)
# Out:
# Collecting kagglehub
#   Using cached kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from kagglehub) (2.32.5)
# Collecting tqdm (from kagglehub)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: colorama in d:\programming\begineer_deep_learning_project\.venv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Using cached kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglehub
#
#    ---------------------------------------- 0/2 [tqdm]
#    ---------------------------------------- 0/2 [tqdm]
#    ---------------------------------------- 0/2 [tqdm]
#    ---------------------------------------- 0/2 [tqdm]
#    ---------------------------------------- 0/2 [tqdm]
#    ---------------------------------------- 0/2 [tqdm]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-0.3.13 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
# Downloading from https://www.kaggle.com/api/v1/datasets/download/prachi13/customer-analytics?dataset_version_number=1...
# 100%|██████████| 121k/121k [00:00<00:00, 144kB/s]
# Extracting files...
# Path to dataset files: C:\Users\sande\.cache\kagglehub\datasets\prachi13\customer-analytics\versions\1

# %%
import os

print("The data name:-", os.listdir(path))
# Out:
# The data name:- ['Train.csv']

# %%
df=pd.read_csv(os.path.join(path,"Train.csv"))

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined
